# %%
import pandas as pd
import io
import os.path
sys.path.append("../FiberPho_Main/")
import FiberClass as fc
print(os.path.abspath(fc.__file__))
# Out:
# /Users/yobae/Desktop/CS Stuff/fiberobj_panel/Yobe_GUI/fiberpho_gui/FiberPho_Main/FiberClass.py

# %%
test_data = "/Users/yobae/Desktop/CS Stuff/fiberobj_panel/Yobe_GUI/fiberpho_gui/tests/src/files/Sample_Data_1.csv"
df = pd.read_csv(test_data)
test_obj = fc.fiberObj(df, 'Test_Object', 1, 2, '02/11', '2:27',
                            0, -1, 'Sample_Data_1')

beh_data = "/Users/yobae/Desktop/CS Stuff/fiberobj_panel/Yobe_GUI/fiberpho_gui/tests/src/files/10_51_30_GFP_Mating_BORIS.csv"
# string instead of file

# %%
test_obj.import_behavior_data(beh_data, "Sample_Beh_1", 'place_holder')
# Out:
# Empty DataFrame
# Columns: [/Users/yobae/Desktop/CS Stuff/fiberobj_panel/Yobe_GUI/fiberpho_gui/tests/src/files/10_51_30_GFP_Mating_BORIS.csv]
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
# test_obj.raw_signal_trace()

# %%
pd.read_csv(beh_data).head(17)
# Out:
#            Observation id                                           10_51_30  \
# 0                     NaN                                                NaN
# 1           Media file(s)                                                NaN
# 2                     NaN                                                NaN
# 3               Player #1  C:/Users/jusa6606/Desktop/video1_2022-01-28T10...
# 4                     NaN                                                NaN
# 5        Observation date                                2022-02-19 12:08:20
# 6                     NaN                                                NaN
# 7             Description                                       10_51_30 GFP
# 8                     NaN                                                NaN
# 9         Time offset (s)                                              0.000
# 10                    NaN                                                NaN
# ...
